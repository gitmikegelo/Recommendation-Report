# %%
import numpy as np 
import pandas as pd 

import seaborn as sns
import matplotlib.pyplot as plt


from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from sklearn.preprocessing import MinMaxScaler
# %matplotlib inline

# %% [markdown]
# # Load Data

# %%
# read and process the charts dataset
charts_df = pd.read_csv('data/spotify_daily_charts.csv')
# transform date column into a datetime column
charts_df['date'] = pd.to_datetime(charts_df['date'])
charts_df.head()
# Out:
#         date  position                track_id            track_name  \
# 0 2017-01-01         1  0kN8xEmgMW9mh7UmDYHlJP  Versace on the Floor
# 1 2017-01-01         2  5uCax9HTNlzGybIStD3vDh  Say You Won't Let Go
# 2 2017-01-01         3  7BKLCZ1jbUBVqRi2FVlTVw                Closer
# 3 2017-01-01         4  2rizacJSyD9S1IQUxUxnsK           All We Know
# 4 2017-01-01         5  5MFzQMkrl1FOOng9tq6R9r      Don't Wanna Know
#
#              artist  streams
# 0        Bruno Mars   185236
# 1      James Arthur   180552
# 2  The Chainsmokers   158720
# 3  The Chainsmokers   130874
# 4          Maroon 5   129656

# %%
# read and process the tracks dataset
tracks_df = pd.read_csv('data/spotify_daily_charts_tracks.csv')
tracks_df.head()
# Out:
#                  track_id            track_name               artist_id  \
# 0  0kN8xEmgMW9mh7UmDYHlJP  Versace on the Floor  0du5cEVh5yTK9QJze8zA0C
# 1  5uCax9HTNlzGybIStD3vDh  Say You Won't Let Go  4IWBUUAFIplrNtaOHcJPRM
# 2  7BKLCZ1jbUBVqRi2FVlTVw                Closer  69GGBxA162lTqCwzJG5jLp
# 3  2rizacJSyD9S1IQUxUxnsK           All We Know  69GGBxA162lTqCwzJG5jLp
# 4  5MFzQMkrl1FOOng9tq6R9r      Don't Wanna Know  04gDigrS5kc9YWfZHwBETP
#
#         artist_name                album_id  duration release_date  \
# 0        Bruno Mars  4PgleR09JVnm3zY1fW3XBA    261240   2016-11-17
# 1      James Arthur  7oiJYvEJHsmYtrgviAVIBD    211466   2016-10-28
# 2  The Chainsmokers  0rSLgV8p5FzfnqlEk4GzxE    244960   2016-07-29
# 3  The Chainsmokers  0xmaV6EtJ4M3ebZUPRnhyb    194080   2016-09-29
# 4          Maroon 5  0fvTn3WXF39kQs9i3bnNpP    214480   2016-10-11
#
#    popularity  danceability  energy   key  loudness  mode  speechiness  \
# 0          75         0.578   0.574   2.0    -6.209   1.0       0.0454
# 1          84         0.358   0.557  10.0    -7.398   1.0       0.0590
# 2          84         0.748   0.524   8.0    -5.599   1.0       0.0338
# 3          69         0.662   0.586   0.0    -8.821   1.0       0.0307
# 4           0         0.783   0.623   7.0    -6.126   1.0       0.0800
#
#    acousticness  instrumentalness  liveness  valence    tempo
# 0         0.196           0.00000    0.0830    0.301  174.152
# 1         0.695           0.00000    0.0902    0.494   85.043
# 2         0.414           0.00000    0.1110    0.661   95.010
# 3         0.097           0.00272    0.1150    0.296   90.000
# 4         0.338           0.00000    0.0975    0.447  100.048

# %%
# merge the charts and tracks dataset
streams_df = charts_df.merge(tracks_df, on='track_id', how='left')
streams_df = streams_df.drop(columns='track_name_y')
streams_df = streams_df.rename(columns={'track_name_x': 'track_name'})
streams_df['date']=pd.to_datetime(streams_df['date'])
streams_df.set_index("date", inplace=True)

streams_df.head()
# Out:
#             position                track_id            track_name  \
# date
# 2017-01-01         1  0kN8xEmgMW9mh7UmDYHlJP  Versace on the Floor
# 2017-01-01         1  0kN8xEmgMW9mh7UmDYHlJP  Versace on the Floor
# 2017-01-01         2  5uCax9HTNlzGybIStD3vDh  Say You Won't Let Go
# 2017-01-01         2  5uCax9HTNlzGybIStD3vDh  Say You Won't Let Go
# 2017-01-01         3  7BKLCZ1jbUBVqRi2FVlTVw                Closer
#
#                       artist  streams               artist_id  \
# date
# 2017-01-01        Bruno Mars   185236  0du5cEVh5yTK9QJze8zA0C
# 2017-01-01        Bruno Mars   185236  0du5cEVh5yTK9QJze8zA0C
# 2017-01-01      James Arthur   180552  4IWBUUAFIplrNtaOHcJPRM
# 2017-01-01      James Arthur   180552  4IWBUUAFIplrNtaOHcJPRM
# 2017-01-01  The Chainsmokers   158720  69GGBxA162lTqCwzJG5jLp
#
#                  artist_name                album_id  duration release_date  \
# date
# 2017-01-01        Bruno Mars  4PgleR09JVnm3zY1fW3XBA  261240.0   2016-11-17
# 2017-01-01        Bruno Mars  4PgleR09JVnm3zY1fW3XBA  261240.0   2016-11-17
# 2017-01-01      James Arthur  7oiJYvEJHsmYtrgviAVIBD  211466.0   2016-10-28
# 2017-01-01      James Arthur  7oiJYvEJHsmYtrgviAVIBD  211466.0   2016-10-28
# 2017-01-01  The Chainsmokers  0rSLgV8p5FzfnqlEk4GzxE  244960.0   2016-07-29
#
#             ...  energy   key  loudness  mode  speechiness  acousticness  \
# date        ...
# 2017-01-01  ...   0.574   2.0    -6.209   1.0       0.0454         0.196
# 2017-01-01  ...   0.574   2.0    -6.209   1.0       0.0454         0.196
# 2017-01-01  ...   0.557  10.0    -7.398   1.0       0.0590         0.695
# 2017-01-01  ...   0.557  10.0    -7.398   1.0       0.0590         0.695
# 2017-01-01  ...   0.524   8.0    -5.599   1.0       0.0338         0.414
#
#             instrumentalness  liveness  valence    tempo
# date
# 2017-01-01               0.0    0.0830    0.301  174.152
# 2017-01-01               0.0    0.0830    0.301  174.152
# 2017-01-01               0.0    0.0902    0.494   85.043
# 2017-01-01               0.0    0.0902    0.494   85.043
# 2017-01-01               0.0    0.1110    0.661   95.010
#
# [5 rows x 22 columns]

# %%
artists_df = pd.read_csv('data/spotify_daily_charts_artists_edited.csv')
artists_df["OPM"]=np.where(artists_df.genres.str.contains('opm'),1,0)

streams_df_opm=pd.merge(streams_df.reset_index(),artists_df[["artist_id","OPM"]], on="artist_id", how="left")
streams_df_opm.set_index("date")
streams_df_opm=streams_df_opm[streams_df_opm.OPM==1]
streams_df_opm.set_index('date',inplace=True)
streams_df_opm.head()
# Out:
#             position                track_id  \
# date
# 2017-01-01        25  2IMODbij0lZ5CuAjZi0IDE
# 2017-01-01        40  0YyM8aEdbjGfLWPn6fdcn7
# 2017-01-01        46  6NFKf8vBApSvtzkapYmnVR
# 2017-01-01        50  6M21eWbEw74XDdoQsNIinq
# 2017-01-01        55  3T8yMLawoliJaN1hAGFFmv
#
#                                                    track_name  \
# date
# 2017-01-01                                               Sila
# 2017-01-01                                     Pasensya Ka Na
# 2017-01-01                                            Tadhana
# 2017-01-01  Malaya (Camp Sawi Original Motion Picture Soun...
# 2017-01-01                                           Sigurado
#
#                       artist  streams               artist_id  \
# date
# 2017-01-01               SUD    70631  0jKQrxK2zHqxyOAyIMrUQt
# 2017-01-01  Silent Sanctuary    52955  4nGp682WMiKS4X217kPw8C
# 2017-01-01    Up Dharma Down    48330  3wbCeEPAW6po7J46netxMT
# 2017-01-01  Moira Dela Torre    39075  0rZRTXEmmPmx6gt92tBqIc
# 2017-01-01    Up Dharma Down    34520  3wbCeEPAW6po7J46netxMT
#
#                  artist_name                album_id  duration release_date  \
# date
# 2017-01-01               SUD  0qwujayb77utSpftsXjdP3  326000.0   2015-07-31
# 2017-01-01  Silent Sanctuary  38jqi8VvSax4miNL2cacD1  241029.0   2015-04-08
# 2017-01-01    Up Dharma Down  4SjshYHT8OeSHB6zun2Hxx  222446.0   2012-12-07
# 2017-01-01  Moira Dela Torre  52xu8EP3ABmpNk0LUzF3ih  254249.0   2017-09-18
# 2017-01-01    Up Dharma Down  5bRwSxYckOjIw3oISF6MQk  339661.0   2017-01-02
#
#             ...   key  loudness  mode  speechiness  acousticness  \
# date        ...
# 2017-01-01  ...   9.0    -6.100   1.0       0.0457        0.0104
# 2017-01-01  ...  11.0   -15.073   1.0       0.0310        0.5190
# 2017-01-01  ...   6.0   -13.200   1.0       0.0369        0.1650
# 2017-01-01  ...   7.0   -14.847   1.0       0.0383        0.8520
# 2017-01-01  ...  11.0    -8.813   1.0       0.0385        0.2950
#
#             instrumentalness  liveness  valence    tempo  OPM
# date
# 2017-01-01          0.000000    0.1090    0.280  124.570  1.0
# 2017-01-01          0.000000    0.0669    0.265   84.007  1.0
# 2017-01-01          0.029600    0.0809    0.511  155.982  1.0
# 2017-01-01          0.000005    0.3210    0.108  114.694  1.0
# 2017-01-01          0.027100    0.1110    0.963  113.010  1.0
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Chart Color Pallette

# %%
#Color Pallette
color1="#F2EFDC"
color2="#1F1F1F"
color3="#FFFFFF"

#Secondary Colors
color4="skyblue"
color5="#58D68D"
color6="#F5CBA7"
color7="#F9E79F"
color8="#C39BD3"
color9="FDD4FD"

# %%
def plot_charts(artist,selected_color=color2, bg_color=color1):
    data1=streams_df[streams_df.artist==artist]['streams'].resample("MS").sum()/1000000
    #data2=streams_df[streams_df.artist==artist]['track_id'].resample("MS").count()
    data2=streams_df[streams_df.artist==artist]['streams'].resample("MS").sum().cumsum()/1000000
    data3=data1.pct_change()
    data4=streams_df[streams_df.artist==artist]['position'].resample("MS").mean()

    #line chart of monthly streams
    fig= plt.figure(figsize=(15,4), dpi=200)
    ax1 = fig.add_subplot(141)
    ax2 = fig.add_subplot(142)
    ax3 = fig.add_subplot(143)
    ax4 = fig.add_subplot(144)
    #default is line so you can omit kind= parameter
    
    '''
    data1[:-1].plot(ax=ax1, kind='line')
    data2.plot(ax=ax2, kind='line')
    data3[:-1].plot(ax=ax3, kind='line')
    data4[:-1].plot(ax=ax4, kind='line')
    '''
    
    
    #'''
    #selected_color=color3
    data1.plot(ax=ax1, kind='line', color=selected_color)
    data2.plot(ax=ax2, kind='line' , color=selected_color)
    data3.plot(ax=ax3, kind='line', color=selected_color)
    data4.plot(ax=ax4, kind='line', color=selected_color)
    #'''
    


    #Uncomment for cleaner x labels
    #ax1.set_xticklabels([x.strftime('%Y-%m') for x in ar_streams.index])

    #ax1.set_xlabel('Date')
    ax1.set_ylabel('common ylabel')

    ax1.set_title('Monthly Streams (%s)' % artist)
    ax2.set_title('Cumulative Streams')
    ax3.set_title('Monthly % Change')
    ax4.set_title('Avg Position in the Top 200')

    ax1.set_facecolor(bg_color)
    ax2.set_facecolor(bg_color)
    ax3.set_facecolor(bg_color)
    ax4.set_facecolor(bg_color)
    
    ax4.set_yticks([1]+np.arange(0, 210, 50).tolist())
    ax4.set_ylim([200, 1])

# %% [markdown]
# # Artist EDA- I Belong To The Zoo

# %% [markdown]
# ## Narrative- Declining Streams, No Recent Hits

# %%
plot_charts("I Belong to the Zoo",color2)

# %%
streams_df[streams_df.artist=="I Belong to the Zoo"].reset_index().groupby(["track_id","track_name"]).agg( \
                                                                                total_streams=("streams","sum"),
                                                                                first_appearance=("date","min"), 
                                                                                last_appearance=("date","max"),
                                                                                avg_position=("position","mean")).reset_index()
# Out:
#                  track_id                    track_name  total_streams  \
# 0  1X4l4i472kW5ofFP8Xo0x0         Sana - Single Version      136668347
# 1  5NXdUJ3Z2jhlp2u1cj6f7m  Balang Araw - Single Version       44989282
#
#   first_appearance last_appearance  avg_position
# 0       2018-07-22      2022-09-15     63.805316
# 1       2018-10-26      2020-09-12     71.159278

# %% [markdown]
# ## Learning From 2 Hit Songs

# %%
zoo_df=pd.read_csv("data_sp/zoo_tracks_data.csv")

scaler = MinMaxScaler()
zoo_df['loudness'] = scaler.fit_transform(zoo_df[['loudness']])
zoo_df['tempo'] =  scaler.fit_transform(zoo_df[['tempo']])
zoo_df.head()
# Out:
#    Unnamed: 0                    track_name                track_id  \
# 0           0         Sana - Single Version  1X4l4i472kW5ofFP8Xo0x0
# 1           1  Balang Araw - Single Version  5NXdUJ3Z2jhlp2u1cj6f7m
# 2           2             Game of Questions  6KTjHpX77i9Ge395Qzo40h
# 3           3                          Oras  2W8lOPzh50eyop8MTvcHjT
# 4           4               Patawad, Paalam  5QJYLlZvfZHX1wUTrgROru
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.660   0.373    7  0.574248     1       0.0290         0.701
# 1         0.523   0.391    7  0.439260     1       0.0298         0.395
# 2         0.350   0.321    7  0.531903     1       0.0289         0.856
# 3         0.425   0.320    9  0.000000     1       0.0305         0.273
# 4         0.472   0.288    2  0.541770     1       0.0318         0.865
#
#    instrumentalness  liveness  valence     tempo
# 0          0.000000    0.2260    0.348  0.613327
# 1          0.000000    0.1420    0.354  0.760930
# 2          0.000000    0.0969    0.240  0.270897
# 3          0.000024    0.3010    0.207  0.875153
# 4          0.000010    0.1310    0.193  0.058880

# %%
#features = ['danceability', 'energy', 'key', 'loudness', 'mode','speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo']  

#features = ['danceability', 'energy', 'loudness', 'mode', 'acousticness', 'liveness', 'valence', 'tempo']  

features = ['tempo','acousticness','danceability', 'loudness','energy','valence'  , 'liveness',]  

columns_to_view = ['track_id'] + features

# %%
df_features = zoo_df[columns_to_view].copy()

#df_features['artist'] = [artist if artist in comb_names else 'all else'
                       #for artist in df_features['artist_name'].values]
    
# set multiindex
df_features = df_features.set_index(['track_id'])

# reshape by pd.stack to achieve shape demanded by boxplot
df_features_stacked = pd.DataFrame({'value': df_features.stack()})
df_features_stacked = df_features_stacked.reset_index()
df_features_stacked = df_features_stacked.rename(columns={'level_1': 'feature'})

df_features_stacked["track_id"]=df_features_stacked["track_id"].apply(lambda x:
                                                                      "Hit Songs" if ( (x=="1X4l4i472kW5ofFP8Xo0x0") | \
                                                                        (x=="5NXdUJ3Z2jhlp2u1cj6f7m")) else 
                                                                       "Other Songs")

    
df_features_stacked
# Out:
#         track_id       feature     value
# 0      Hit Songs         tempo  0.613327
# 1      Hit Songs  acousticness  0.701000
# 2      Hit Songs  danceability  0.660000
# 3      Hit Songs      loudness  0.574248
# 4      Hit Songs        energy  0.373000
# ..           ...           ...       ...
# 170  Other Songs  danceability  0.444000
# 171  Other Songs      loudness  0.610462
# 172  Other Songs        energy  0.271000
# 173  Other Songs       valence  0.254000
# 174  Other Songs      liveness  0.109000
#
# [175 rows x 3 columns]

# %%
plt.figure(figsize=(15, 6), dpi=200)
ax = plt.subplot(111)

sns.boxplot(data=df_features_stacked, x='feature', y='value',  hue='track_id', ax=ax,
            hue_order=['Hit Songs',"Other Songs"] , palette=[color4, color1])#, boxprops=dict(alpha=.3))

ax.legend(loc='upper center', bbox_to_anchor=(
   0.5, -0.1), frameon=False, ncol=3)
ax.axvspan(-0.625, 2.5, facecolor=color6, alpha=0.1)

plt.title("Audio Features- I Belong to the Zoo Hit Songs vs Their Other Songs",size=15)
# Out:
# Text(0.5, 1.0, 'Audio Features- I Belong to the Zoo Hit Songs vs Their Other Songs')

# %% [markdown]
# # Market EDA

# %%
### DF Series into Dictionary
artist_dict=pd.Series(tracks_df.artist_name.values,index=(tracks_df.artist_id)).to_dict()
#arr_df['track_id'] = arr_df['track_id'].apply(lambda x:bnb_tracks_dict.get(x))

#artist_dict

# %%
streams_df.columns
# Out:
# Index(['position', 'track_id', 'track_name', 'artist', 'streams', 'artist_id',
#        'artist_name', 'album_id', 'duration', 'release_date', 'popularity',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo'],
#       dtype='object')

# %%
df_3_groups = streams_df_opm\
    .groupby(['artist_id'])['streams']\
    .resample('M').sum().reset_index()\
    .sort_values('streams', ascending=False)
#df_ed = df_ed.set_index('date')
df_3_groups['album_name'] = df_3_groups['artist_id'].apply(lambda x:
                                              'Big3' if ( (artist_dict.get(x) == 'Arthur Nery') | \
                                                         (artist_dict.get(x) == 'Adie') |
                                                         (artist_dict.get(x) == 'Zack Tabudlo') ) else
                                              'Dominant Bands' if ((artist_dict.get(x) == 'Ben&Ben') |
                                                         (artist_dict.get(x) == 'NOBITA'))
                                                           else 'OPM Others')

#df_3_groups = df_3_groups.set_index('date')
df_3_groups=df_3_groups.groupby(["date","album_name"])[["streams"]].sum().reset_index()
df_3_groups
# Out:
#           date      album_name   streams
# 0   2017-01-31      OPM Others  34692115
# 1   2017-02-28      OPM Others  37728332
# 2   2017-03-31      OPM Others  45164935
# 3   2017-04-30      OPM Others  40998832
# 4   2017-05-31      OPM Others  39165115
# ..         ...             ...       ...
# 150 2022-08-31  Dominant Bands  29869675
# 151 2022-08-31      OPM Others  92037264
# 152 2022-09-30            Big3  30814853
# 153 2022-09-30  Dominant Bands  17381682
# 154 2022-09-30      OPM Others  51932978
#
# [155 rows x 3 columns]

# %%
plt.figure(figsize=(4, 2),dpi=200)
ax = plt.subplot(111)

color_list = ['skyblue', color2, color1]
# reshape
data = df_3_groups.pivot(index='date', columns='album_name', values='streams')
# normalize with monthly sums
data[data.columns] = 100*data[data.columns].div(data.sum(axis=1), axis=0)
data=data.loc['2021-01-01':'2022-12-31']

# plot
data.plot.area(ax=ax, lw=0, color=color_list)

# custom ticks
plt.yticks(np.arange(0, 120, 20), [str(x)+'%' for x in np.arange(0, 120, 20)])
plt.ylabel('Streams')
plt.ylim([0, 100])

plt.xlabel('')
plt.title("5 Mainstays vs Other OPM Artists")
# Put a legend below current axis
#ax.legend(loc='upper center', bbox_to_anchor=(
    #0.5, -0.25), frameon=False, ncol=3)

ax.legend(loc='right',ncol=1,prop={'size': 6},bbox_to_anchor=(
    0.35,0.85))
    
#--------------------------------------------------------------

# %% [markdown]
# # Learning From Mainstay Artists

# %% [markdown]
# ## Track Composition

# %%
tracks_dict=pd.Series(tracks_df.track_name.values,index=(tracks_df.track_id)).to_dict()
top5_names=["Arthur Nery", "Adie","Zack Tabudlo","Ben&Ben","NOBITA"]
artist_name=["I Belong to the Zoo"]
comb_names=top5_names

# %%
mainstay_df=pd.read_csv("data_sp/tracks_data.csv")

scaler = MinMaxScaler()
mainstay_df['loudness'] = scaler.fit_transform(mainstay_df[['loudness']])
mainstay_df['tempo'] =  scaler.fit_transform(mainstay_df[['tempo']])
mainstay_df
# Out:
#     Unnamed: 0                    track_name                track_id  \
# 0            0                      Isa lang  0HAG6nIiEKd75yGpovuSJQ
# 1            1                       Pagsamo  0WZqHCoOBXqgCCIsUZLC2a
# 2            2                          Higa  7gfrASeOt73YWvpIv1fU8E
# 3            3                     Happy w u  0EA8jl8Wje9ALRKC8Qlzyt
# 4            4                         Binhi  092cPwFlwBXdB3QF3X469W
# 22       0.0248       0.11200          0.000000    0.1900   0.2080  0.316809
# 23       0.0305       0.08800          0.000000    0.3620   0.1830  0.483256
# 24       0.0320       0.42300          0.000002    0.4350   0.0979  0.581970
# 25       0.0334       0.40900          0.000000    0.1070   0.5470  0.449652
# 26       0.0307       0.79600          0.127000    0.0906   0.2060  0.487230
# 27       0.0373       0.35300          0.000002    0.1080   0.4470  0.175511
# 28       0.0358       0.52900          0.000241    0.2800   0.4690  0.666789
# 29       0.0308       0.67300          0.000000    0.2320   0.1630  0.476825
# 30       0.0308       0.10700          0.000000    0.3570   0.7500  0.443196
# 31       0.0320       0.43200          0.000002    0.1140   0.2740  0.975950
# 32       0.0372       0.91300          0.000000    0.0891   0.2050  0.485755
# 33       0.0301       0.77600          0.000005    0.1520   0.2950  0.557462
# 34       0.0295       0.58200          0.000000    0.2340   0.2240  0.673936
# 35       0.0367       0.11300          0.000049    0.1140   0.4980  0.117032
# 36       0.0253       0.50600          0.000000    0.4040   0.5230  0.291960
# 37       0.0485       0.70000          0.000021    0.1860   0.3420  0.223885
# 38       0.0316       0.29200          0.000010    0.3930   0.4010  0.999608
# 39       0.0336       0.12000          0.000000    0.0924   0.3230  0.507739
# 40       0.0557       0.41200          0.000000    0.1260   0.3750  1.000000
# 41       0.0297       0.29200          0.000001    0.2830   0.3210  0.666989
# 42       0.0389       0.57600          0.000003    0.3670   0.1960  0.592874
# 43       0.0309       0.27200          0.000000    0.0892   0.6560  0.699469
# 44       0.0316       0.42700          0.000003    0.0742   0.1120  0.596565
# 45       0.0346       0.45800          0.000012    0.1340   0.1290  0.557346
# 46       0.0287       0.02250          0.000011    0.2840   0.4450  0.325339
# 47       0.0315       0.29800          0.000000    0.1210   0.2390  0.438439
# 48       0.0290       0.70100          0.000000    0.2260   0.3480  0.557179
# 49       0.0298       0.39500          0.000000    0.1420   0.3540  0.665623
# 50       0.0247       0.08400          0.000000    0.1860   0.1740  0.574414
# 51       0.0272       0.07800          0.000000    0.1570   0.3500  0.673370
# 52       0.0318       0.86500          0.000010    0.1310   0.1930  0.149828
# 53       0.0305       0.27300          0.000024    0.3010   0.2070  0.749542
# 54       0.0289       0.85600          0.000000    0.0969   0.2400  0.305596
# 55       0.0328       0.77000          0.000000    0.1350   0.4100  0.642439
# 56       0.0487       0.49200          0.000000    0.1960   0.4630  0.583136
# 57       0.0539       0.00711          0.000000    0.0847   0.4740  0.841267

# %%
features = ['danceability', 'energy', 'key', 'loudness', 'mode',\
                     'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo']  

features = ['danceability', 'energy', 'loudness',\
                      'acousticness', 'liveness', 'valence', 'tempo']  

features = ['danceability', 'energy','valence', 'loudness' , 'tempo', 'liveness','acousticness',]  

columns_to_view = ['artist_name', 'track_name'] + features

# %%
df_features = mainstay_df[columns_to_view].copy()

#df_features['artist'] = [artist if artist in comb_names else 'all else'
                       #for artist in df_features['artist_name'].values]
    
# set multiindex
df_features = df_features.set_index(['track_name', 'artist_name'])

# reshape by pd.stack to achieve shape demanded by boxplot
df_features_stacked = pd.DataFrame({'value': df_features.stack()})
df_features_stacked = df_features_stacked.reset_index()
df_features_stacked = df_features_stacked.rename(columns={'level_2': 'feature'})

    
df_features_stacked
# Out:
#     track_name          artist_name       feature     value
# 0     Isa lang          Arthur Nery  danceability  0.429000
# 1     Isa lang          Arthur Nery        energy  0.464000
# 2     Isa lang          Arthur Nery       valence  0.375000
# 3     Isa lang          Arthur Nery      loudness  0.601161
# 4     Isa lang          Arthur Nery         tempo  0.509555
# ..         ...                  ...           ...       ...
# 401     Balita  I Belong to the Zoo       valence  0.474000
# 402     Balita  I Belong to the Zoo      loudness  1.000000
# 403     Balita  I Belong to the Zoo         tempo  0.841267
# 404     Balita  I Belong to the Zoo      liveness  0.084700
# 405     Balita  I Belong to the Zoo  acousticness  0.007110
#
# [406 rows x 4 columns]

# %%
plt.figure(figsize=(15, 6), dpi=200)
ax = plt.subplot(111)

sns.boxplot(data=df_features_stacked, x='feature', y='value',  hue='artist_name', ax=ax,
            hue_order=['I Belong to the Zoo']+top5_names, palette=[color4,color1,color5,"#F5CBA7","#F9E79F","#C39BD3"])

#)#


ax.legend(loc='upper center', bbox_to_anchor=(
   0.5, -0.1), frameon=False, ncol=3)

ax.set_ylim([-0.0999, 1.2])
#text(x, y, s, bbox=dict(facecolor='red', alpha=0.5))

ax.text(0.2, 0.95,'Similar',fontsize=12,bbox=dict(facecolor='white', edgecolor='black', boxstyle='round'),
     horizontalalignment='left',
     verticalalignment='top',
     transform = ax.transAxes)

ax.text(0.68, 0.95,'Different',fontsize=12,bbox=dict(facecolor='white', edgecolor='black', boxstyle='round'),
     horizontalalignment='left',
     verticalalignment='top',
     transform = ax.transAxes)


ax.axvspan(2.5, 6.8, facecolor=color6, alpha=0.15)
ax.set_title("Comparison of Audio Features- I Belong to the Zoo vs Mainstay Artists",fontsize=15)
# Out:
# Text(0.5, 1.0, 'Comparison of Audio Features- I Belong to the Zoo vs Mainstay Artists')

# %% [markdown]
# ## Promotional/Marketing Strategies

# %%
streams_df
# Out:
#             position                track_id            track_name  \
# date
# 2017-01-01         1  0kN8xEmgMW9mh7UmDYHlJP  Versace on the Floor
# 2017-01-01         1  0kN8xEmgMW9mh7UmDYHlJP  Versace on the Floor
# 2017-01-01         2  5uCax9HTNlzGybIStD3vDh  Say You Won't Let Go
# 2017-01-01         2  5uCax9HTNlzGybIStD3vDh  Say You Won't Let Go
# 2017-01-01         3  7BKLCZ1jbUBVqRi2FVlTVw                Closer
# ...              ...                     ...                   ...
# 2022-09-15       196  2Mo4pOpCYXOu33856sMQLh      Make It With You
# 2022-09-15       197  2GThBgzZoZfz0lx1JjBwfe            Those Eyes
# 2022-09-15       198  0VjIjW4GlUZAMYd2vXMi3b       Blinding Lights
# 2022-09-15       199  6mQzZ2aRnKSNgckAehBgwD                  Beer
# 2022-09-15       200  0kDeE8TezXDY1QadpjAQQq             Bahala Na
#
#                       artist  streams               artist_id  \
# date
# 2017-01-01        Bruno Mars   185236  0du5cEVh5yTK9QJze8zA0C
# 2017-01-01        Bruno Mars   185236  0du5cEVh5yTK9QJze8zA0C
# 2017-01-01      James Arthur   180552  4IWBUUAFIplrNtaOHcJPRM
# 2017-01-01      James Arthur   180552  4IWBUUAFIplrNtaOHcJPRM
# 2017-01-01  The Chainsmokers   158720  69GGBxA162lTqCwzJG5jLp
# ...                      ...      ...                     ...
# 2022-09-15           Ben&Ben    41035  4DAcJXcjX0zlQAZAPAx4Zb
# 2022-09-15          New West    40950  69bG9tC62d8oTFC9aTTosn
# 2022-09-15        The Weeknd    40898  1Xyo4u8uXC1ZmMpatF05PJ
# 2022-09-15    The Itchyworms    40815  5cYJYBMg1n71v7cvthr1SO
# 2022-09-15          Kenaniah    40427  2owtRYReKCG1n2AAS5AcpS
#
#                  artist_name                album_id  duration release_date  \
# date
# 2017-01-01        Bruno Mars  4PgleR09JVnm3zY1fW3XBA  261240.0   2016-11-17
# 2017-01-01        Bruno Mars  4PgleR09JVnm3zY1fW3XBA  261240.0   2016-11-17
# 2017-01-01      James Arthur  7oiJYvEJHsmYtrgviAVIBD  211466.0   2016-10-28
# 2017-01-01      James Arthur  7oiJYvEJHsmYtrgviAVIBD  211466.0   2016-10-28
# 2017-01-01  The Chainsmokers  0rSLgV8p5FzfnqlEk4GzxE  244960.0   2016-07-29
# ...                      ...                     ...       ...          ...
# 2022-09-15           Ben&Ben  3cHbJm4cKnGephP4UYxIEv  209782.0   2019-12-13
# 2022-09-15          New West  4iRLB4gc24HFvjwRc8hDdg  220750.0   2019-05-10
# 2022-09-15        The Weeknd  4yP0hdKOZPNshxUOjY0cZj  200040.0   2020-03-20
# 2022-09-15    The Itchyworms  6WzFODPnZ5SW1qTvTELSxW  364106.0         2006
# 2022-09-15          Kenaniah  38K1I3Ij268DtPqJqYcY6U  228688.0   2022-07-27
#
#             ...  energy   key  loudness  mode  speechiness  acousticness  \
# date        ...
# 2017-01-01  ...   0.574   2.0    -6.209   1.0       0.0454       0.19600
# 2017-01-01  ...   0.574   2.0    -6.209   1.0       0.0454       0.19600
# 2017-01-01  ...   0.557  10.0    -7.398   1.0       0.0590       0.69500
# 2017-01-01  ...   0.557  10.0    -7.398   1.0       0.0590       0.69500
# 2017-01-01  ...   0.524   8.0    -5.599   1.0       0.0338       0.41400
# ...         ...     ...   ...       ...   ...          ...           ...
# 2022-09-15  ...   0.458   4.0   -10.711   1.0       0.0485       0.70000
# 2022-09-15  ...   0.351   4.0    -8.043   1.0       0.0281       0.72700
# 2022-09-15  ...   0.730   1.0    -5.934   1.0       0.0598       0.00146
# 2022-09-15  ...   0.693   7.0    -3.967   1.0       0.0265       0.51700
# 2022-09-15  ...   0.404  11.0   -11.168   1.0       0.0861       0.42400
#
#             instrumentalness  liveness  valence    tempo
# date
# 2017-01-01          0.000000    0.0830    0.301  174.152
# 2017-01-01          0.000000    0.0830    0.301  174.152
# 2017-01-01          0.000000    0.0902    0.494   85.043
# 2017-01-01          0.000000    0.0902    0.494   85.043
# 2017-01-01          0.000000    0.1110    0.661   95.010
# ...                      ...       ...      ...      ...
# 2022-09-15          0.000021    0.1860    0.342   86.877
# 2022-09-15          0.000039    0.3190    0.243  119.948
# 2022-09-15          0.000095    0.0897    0.334  171.005
# 2022-09-15          0.000005    0.1120    0.472   84.954
# 2022-09-15          0.000101    0.0959    0.762  122.001
#
# [420460 rows x 22 columns]

# %%
streams_df[(streams_df.artist=="Zack Tabudlo") & (streams_df.track_name.str.contains("Bini"))].groupby("track_name")[["streams"]].sum()
# Out:
#                                                 streams
# track_name
# Binibini                                       92920899
# Binibini (Last Day On Earth) (feat. James TW)     28429

# %%
def plot_heatmap(artist,figx,figy):
    streams_df_no_dup=streams_df.copy()
    #streams_df_no_dup["track_name"]=streams_df_no_dup["track_name"].str.strip()
    df_artist = streams_df_no_dup[streams_df_no_dup['artist'] == artist].groupby('track_name')[['streams']]\
    .resample('M').sum()
    df_artist = df_artist.reset_index()
    df_artist['track_name'] = df_artist['track_name'].apply(lambda x: x.split('(')[0])\
        .apply(lambda x: x.split(' - ')[0])
    df_artist["track_name"]=df_artist["track_name"].str.strip()
    
    df_artist=df_artist.groupby(["date","track_name"])[["streams"]].sum().reset_index()
    #print(df_artist)

    #------------------------------------------------------
    arr_df = df_artist.pivot(index='track_name', columns='date', values='streams')
    # divide by 1M to show streams in millions
    arr_df = arr_df/1000000
    arr_df.fillna(0, inplace=True)
    arr_df['total_streams'] = arr_df.sum(axis=1)
    #arr_df = arr_df.sort_values('total_streams',ascending=False)
    arr_df

    #----------------------------------------------------------------------------
    plt.figure(figsize=(figx, figy),dpi=200)
    ax = plt.subplot(111)

    # get all month columns and specify format for xticks
    moncols = arr_df.columns[:-1]
    yymm_cols = pd.Series(moncols.values).apply(lambda x: x.strftime('%Y-%m'))

    sns.heatmap(arr_df[moncols], ax=ax,
                #vmin=0, vmax=0.5,
                #cmap='Greens',
                cmap=sns.color_palette(colors),
                #cmap=ccmap,
                cbar_kws={'label': 'million streams', 'ticks': np.arange(0, 20, 1)},
                xticklabels=yymm_cols, yticklabels=True, linecolor='0.8',linewidths=0.1)

    plt.ylabel('')
    plt.xlabel('')
    plt.show()

# %%
#Custom Color Scheme for the graphs
colors=["#f9f8ef","#ddd6a4","#c8bd6c","#a89c3f"]
#colors=["#eff9f8","#a4ddd6","#6cc8bd","#3fa89c"]
#colors=["#f4f4f4","#b4b4b4","#8e8e8e","#686868"]

# %% [markdown]
# ### I Belong to the Zoo

# %%
plot_heatmap("I Belong to the Zoo",13, 1.3)

# %% [markdown]
# ### Zack Tabudlo

# %%
plot_heatmap("Zack Tabudlo",8, 4)

# %% [markdown]
# ### Arthur Nery

# %%
plot_heatmap("Arthur Nery",8, 3)

# %% [markdown]
# ### Adie

# %%
plot_heatmap("Adie",8, 3)

# %% [markdown]
# ### Ben&Ben

# %%
plot_heatmap("Ben&Ben",15, 15)

# %% [markdown]
# ### NOBITA

# %%
plot_heatmap("NOBITA",13, 2)
