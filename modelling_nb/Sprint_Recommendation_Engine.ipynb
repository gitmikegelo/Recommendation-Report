# %% [markdown]
# # Content-Based Recommendation Engine

# %% [markdown]
# This recommendation engine takes in a seed track and outputs track recommendations based on similarity measures

# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler


# %matplotlib inline

# %% [markdown]
# ## 1. Read the recommendation pool

# %%
#read data
chart_tracks_df=pd.read_csv("Reco Pool w Probabilities.csv")
chart_tracks_df = chart_tracks_df.dropna()
#normalize loudness and tempo
scaler = MinMaxScaler()
chart_tracks_df['loudness'] = scaler.fit_transform(chart_tracks_df[['loudness']])
chart_tracks_df['tempo'] =  scaler.fit_transform(chart_tracks_df[['tempo']])
chart_tracks_df.head()
# Out:
#                  track_id       track_name               artist_id  \
# 0  4IvFOa1p68SZOYfnn81vv1        Samalamig  5GdspZ491zr64zzwVJJjJZ
# 1  19AlSgwI1midC2PU1TDkeF  Pekeng Kaibigan  1vcXQE9gZOF9PCAtdtT51L
# 2  54b8IPvheXDpro2VR2rWAS            Ivana  2EGJbNf0Hva2C2N6hvhMXD
# 3  5bSvsXRBUjGe8pGScU0hPz            Ivana  2EGJbNf0Hva2C2N6hvhMXD
# 4  0pobQmvHou3syiOi6DRqiC           Manila  4sEykiNSzZbkFkNXTb1bVd
#
#   artist_name                album_id  duration release_date  popularity  \
# 0     Shehyee  6NfArxsGcyiEJURN4NGgFc    253469   2002-12-18           2
# 1     Geo Ong  3A5uVKYCA9EJ6AIIIvHvdc    249085   2019-02-11           0
# 2   Soulstice  10stEx5J17TekHdjeh9dOJ    246550   2020-01-06           2
# 3   Soulstice  2zrFpbXrA54V8lCCQQhQRA    246550   2020-01-06           0
# 4      Hotdog  6KnvLQbkDLy4ZEpt8ONWYR    184146   2008-06-18           2
#
#    danceability  energy  ...     streams  predicted_genre_id  predicted_genre  \
# 0         0.859   0.667  ...   1489819.0                   3          opm rap
# 1         0.953   0.580  ...     68773.0                   3          opm rap
# 2         0.870   0.483  ...  13743952.0                   3          opm rap
# 3         0.871   0.480  ...   4212911.0                   3          opm rap
# 4         0.801   0.538  ...     28942.0                   3          opm rap
#
#    predicted_genre_prob  predicted_opm acoustic_prob  \
# 0              0.982463                     0.000195
# 1              0.980860                     0.000494
# 2              0.973431                     0.000073
# 3              0.972775                     0.000069
# 4              0.944196                     0.004161
#
#    predicted_opm dance_prob  predicted_opm jazz_prob  predicted_opm rap_prob  \
# 0                  0.002257                 0.005592                0.982463
# 1                  0.005460                 0.003030                0.980860
# 2                  0.001958                 0.001852                0.973431
# 3                  0.002064                 0.001744                0.972775
# 4                  0.006871                 0.018908                0.944196
#
#    predicted_opm reggae_prob  predicted_opm rock_prob
# 0                   0.008270                 0.001223
# 1                   0.009007                 0.001149
# 2                   0.022299                 0.000387
# 3                   0.022972                 0.000376
# 4                   0.017624                 0.008240
#
# [5 rows x 29 columns]

# %%
chart_tracks_df.shape
# Out:
# (631, 29)

# %% [markdown]
# ## 2. Input Seed Track

# %%
feature_cols = ['danceability', 'energy', 'loudness', 'speechiness', 'acousticness', 'instrumentalness',\
                'liveness', 'valence', 'tempo']

# %%
seed_track_data = pd.read_csv("tracks_data_with_proba.csv",index_col=0)

# %%
seed_track_data
# Out:
#                               track_name                track_id  \
# Unnamed: 0
# 38                              Lifetime  3X9c4tBzSdGhlO4Fx3WYgW
# 57                                Balita  62y4i6e9QVug3Nf7gf7i9P
# 45                 Vie (Sabihin Mo Kung)  6FmoxZRTJrSCaZR3rjEv3W
# 30                     Paninindigan Kita  5d9Rka4T0szdC1MobhtXrV
# 24                              Binibini  55RMhrPQYA6vLu5YMgXxFD
# 41                           Paano Uusad  7oqMwb6Don3sa3BtzuKv0G
# 51                           Balang Araw  0z6gEZUTCnAQpaAAh1xnhy
# 15                   You'll Be Safe Here  4whLOE7hwNIAykoMcSZmvO
# 35                       Maybe The Night  1yDiru08Q6omDOGkZMPnei
# 28            Iba (ft. Moira Dela Torre)  6FTQJjBTyBmjluSDwzHMNh
# 31            Sa Susunod na Habang Buhay  3PgjBOoA5OytNGkglObpOd
# 16                                  Luha  2f0T6IDfPT9sNJqqJxEOTR
# 29                The Ones We Once Loved  6YjKd9oPXKqjLUVPo4Y0oi
# 43                                 Totoo  65C2UAv6EgIivHLmxBhvgx
# 32                                Leaves  6wdCelHrPh7UfliNjwRTUv
# 52                       Patawad, Paalam  5QJYLlZvfZHX1wUTrgROru
# 11                             Paraluman  2jbf9EytR7fzpSrPWAYCf9
# 54                     Game of Questions  6KTjHpX77i9Ge395Qzo40h
# 21                         Asan Ka Na Ba  5MYPzdIWgx3pMLRGlq2fVq
# 6              Sinag (feat. Sam Benwick)  5DARNIgi6aaJxGD5SKAUal
# 42                        Di Na Mag-iisa  3YaKDCOO28ZzQh059eAgdt
# 39                             Ikaw Lang  16iRlyUMJVPqz62DlomMre
# 3                              Happy w u  0EA8jl8Wje9ALRKC8Qlzyt
# 2                                   Higa  7gfrASeOt73YWvpIv1fU8E
# 4                                  Binhi  092cPwFlwBXdB3QF3X469W
# 13                                Dungaw  3XlzKAS2zostN3UiBJvLW6
# 5                      TAKE ALL THE LOVE  2v6jmF6VQWS96x6tSg05IC
# 33                          Kathang Isip  3WUEs51GpcvlgU7lehLgLh
# 34                             Araw-Araw  4rG3h1QwgjSSWz8EIjCFrm
# 47                Tayong Dalawa Sa Pasko  6kvTjP9wlYW9qXEa4muMgy
# 53                                  Oras  2W8lOPzh50eyop8MTvcHjT
# 12                               Tahanan  5CUQnKjA6nlteCnxMKsjIu
# 26                                  Pero  1i7JnFAxC15AuF1dsosbYM
# 1                                Pagsamo  0WZqHCoOBXqgCCIsUZLC2a
# 10                                Mahika  47sq83n5WN22ZzYnGn8aTy
# 46                                 Yakap  40AHSwhY60qEOC0TySp9uA
# 49          Balang Araw - Single Version  5NXdUJ3Z2jhlp2u1cj6f7m
# 48                 Sana - Single Version  1X4l4i472kW5ofFP8Xo0x0
# 14                                Kabado  7oLe1cVRqLpoH2NozJ78mh
# 55            The One With The Snowflake  7bjzkR18f3SRsX64rPLbZg
# 9                                Hung Up  5YHXL4ggZEHZUgQBgLF0Oz
# 8                           Cotton Candy  1t19LlMX4aomJ1U9MDzan8
# 18                               Sawa Na  0LoXmqWDjLVi6uHh25DtaP
# 7                            Life Puzzle  42A9RtOizRYgILd4muMvto
# 23                          Habang Buhay  63bmIgH9sS6sX5Sc7MetGq
# 40                           Unang Sayaw  4iRRAvxPPWXQp3mV1rAbPF
# 44                    The Search Is Over  7g7mYjkJzHkCye65pzfK7Q
# 17              Tinatangi (feat. Chrstn)  5Pgssd39LAfVsR9gvUVwU7
# 20                  Give Me Your Forever  4mzP5mHkRvGxdhdGdAH7EJ
# 22                           Nangangamba  1dcNEEtODRVZEevQ20Cgmy
# 50                                  Sana  1ligR6l4uqjSyigzJ4Zgdj
# 37                      Make It With You  2Mo4pOpCYXOu33856sMQLh
# 36                             Pagtingin  5l9g7py8RCblcvbZgGQgSd
# 19                                  Pano  08MFgEQeVLF37EyZ7jcwLc
# 25                                 Yakap  3h8uWt8HNyDNubPSEBgTPG
# 56                                 Maybe  2Qj2gsRuV9Jz3Ivu3pnfPm
# 27                            As You Are  7vu53hQrIoH7UGeh6qcct1
# 0                               Isa lang  0HAG6nIiEKd75yGpovuSJQ
#
#                     artist_name  danceability  energy  key  loudness  mode  \
# Unnamed: 0
# 38                      Ben&Ben         0.386   0.657    7  0.865198     1
# 57          I Belong to the Zoo         0.485   0.891    2  1.000000     1
# 45                       NOBITA         0.686   0.271    7  0.488786     1
# 30                      Ben&Ben         0.624   0.596    4  0.534118     1
# 24                 Zack Tabudlo         0.642   0.374    5  0.429299     1
# 41                       NOBITA         0.430   0.465    7  0.267139     1
# 51          I Belong to the Zoo         0.528   0.527    7  0.773262     1
# 15                         Adie         0.376   0.130   11  0.263003     1
# 35                      Ben&Ben         0.572   0.522    2  0.549467     1
# 28                 Zack Tabudlo         0.563   0.799    2  0.907030     1
# 31                      Ben&Ben         0.311   0.342    2  0.565850     1
# 16                         Adie         0.355   0.179    8  0.262049     1
# 29                      Ben&Ben         0.427   0.301    0  0.648879     0
# 43                       NOBITA         0.576   0.318    6  0.309687     1
# 32                      Ben&Ben         0.447   0.160    6  0.406235     1
# 52          I Belong to the Zoo         0.472   0.288    2  0.619612     1
# 11                         Adie         0.519   0.246    5  0.171306     1
# 54          I Belong to the Zoo         0.350   0.321    7  0.611420     1
# 21                 Zack Tabudlo         0.676   0.768    5  0.819866     0
# 6                   Arthur Nery         0.540   0.287    9  0.245268     1
# 42                       NOBITA         0.497   0.213    7  0.152219     1
# 39                       NOBITA         0.513   0.380   11  0.390727     1
# 3                   Arthur Nery         0.596   0.182    6  0.000000     1
# 2                   Arthur Nery         0.656   0.336    9  0.434707     1
# 4                   Arthur Nery         0.460   0.311    5  0.458804     1
# 13                         Adie         0.613   0.291    5  0.309448     1
# 5                   Arthur Nery         0.491   0.486    5  0.748847     1
# 33                      Ben&Ben         0.491   0.314   10  0.590425     1
# 34                      Ben&Ben         0.475   0.424   11  0.605535     1
# 47                       NOBITA         0.418   0.201    0  0.349531     1
# 53          I Belong to the Zoo         0.425   0.320    9  0.169874     1
# 12                         Adie         0.394   0.366    3  0.409496     1
# 26                 Zack Tabudlo         0.644   0.412    5  0.545888     0
# 1                   Arthur Nery         0.644   0.315    6  0.526642     1
# 10                         Adie         0.635   0.451    7  0.683792     1
# 46                       NOBITA         0.665   0.670    9  0.797519     1
# 49          I Belong to the Zoo         0.523   0.391    7  0.534516     1
# 48          I Belong to the Zoo         0.660   0.373    7  0.646572     1
# 14                         Adie         0.550   0.461    1  0.405360     1
# 55          I Belong to the Zoo         0.489   0.271    4  0.181088     1
# 9                   Arthur Nery         0.549   0.360   11  0.458088     1
# 8                   Arthur Nery         0.473   0.371    1  0.456100     0
# 18                         Adie         0.651   0.417    9  0.462303     1
# 7                   Arthur Nery         0.719   0.234    4  0.160728     1
# 23                 Zack Tabudlo         0.620   0.668    9  0.817958     1
# 40                       NOBITA         0.500   0.397    9  0.346031     1
# 44                       NOBITA         0.331   0.294    9  0.284158     1
# 17                         Adie         0.479   0.463    5  0.546922     1
# 20                 Zack Tabudlo         0.627   0.363    8  0.626451     1
# 22                 Zack Tabudlo         0.620   0.547    1  0.734213     1
# 50          I Belong to the Zoo         0.598   0.502    7  0.741053     1
# 37                      Ben&Ben         0.558   0.458    4  0.420948     1
# 36                      Ben&Ben         0.669   0.420    2  0.599650     1
# 19                 Zack Tabudlo         0.375   0.457    3  0.714649     1
# 25                 Zack Tabudlo         0.738   0.390    8  0.601797     1
# 56          I Belong to the Zoo         0.672   0.569    9  0.624702     0
# 27                 Zack Tabudlo         0.715   0.438   10  0.783919     0
# 0                   Arthur Nery         0.429   0.464    6  0.601161     0
#
#             speechiness  acousticness  ...     tempo  predicted_genre_id  \
# Unnamed: 0                             ...
# 38               0.0316       0.29200  ...  0.999608                   5
# 57               0.0539       0.00711  ...  0.841267                   5
# 45               0.0346       0.45800  ...  0.557346                   0
# 30               0.0308       0.10700  ...  0.443196                   5
# 24               0.0320       0.42300  ...  0.581970                   0
# 41               0.0297       0.29200  ...  0.666989                   5
# 51               0.0272       0.07800  ...  0.673370                   5
# 15               0.0321       0.94300  ...  0.341391                   0
# 35               0.0367       0.11300  ...  0.117032                   5
# 28               0.0358       0.52900  ...  0.666789                   5
# 31               0.0320       0.43200  ...  0.975950                   5
# 16               0.0373       0.90500  ...  0.202309                   0
# 29               0.0308       0.67300  ...  0.476825                   0
# 43               0.0309       0.27200  ...  0.699469                   5
# 32               0.0372       0.91300  ...  0.485755                   0
# 52               0.0318       0.86500  ...  0.149828                   0
# 11               0.0396       0.77400  ...  0.250908                   0
# 54               0.0289       0.85600  ...  0.305596                   0
# 21               0.0294       0.14900  ...  0.383176                   5
# 6                0.0314       0.87600  ...  0.125112                   0
# 42               0.0389       0.57600  ...  0.592874                   0
# 39               0.0336       0.12000  ...  0.507739                   5
# 3                0.0378       0.90300  ...  0.430950                   0
# 2                0.0434       0.45300  ...  0.541943                   0
# 4                0.0319       0.96100  ...  0.534737                   0
# 13               0.0453       0.69600  ...  0.494260                   0
# 5                0.0347       0.28500  ...  0.186682                   5
# 33               0.0301       0.77600  ...  0.557462                   0
# 34               0.0295       0.58200  ...  0.673936                   0
# 47               0.0315       0.29800  ...  0.438439                   5
# 53               0.0305       0.27300  ...  0.749542                   5
# 12               0.0310       0.79900  ...  0.415356                   0
# 26               0.0307       0.79600  ...  0.487230                   0
# 1                0.0339       0.70600  ...  0.000000                   0
# 10               0.0391       0.74200  ...  0.183058                   2
# 46               0.0287       0.02250  ...  0.325339                   5
# 49               0.0298       0.39500  ...  0.665623                   5
# 48               0.0290       0.70100  ...  0.557179                   0
# 14               0.0457       0.76300  ...  0.648862                   0
# 55               0.0328       0.77000  ...  0.642439                   0
# 9                0.0549       0.77100  ...  0.472044                   0
# 8                0.1280       0.69700  ...  0.999509                   3
# 18               0.0265       0.49400  ...  0.399853                   0
# 7                0.0884       0.58600  ...  0.282588                   3
# 23               0.0305       0.08800  ...  0.483256                   5
# 40               0.0557       0.41200  ...  1.000000                   5
# 44               0.0316       0.42700  ...  0.596565                   0
# 17               0.0318       0.77300  ...  0.115083                   0
# 20               0.0291       0.27900  ...  0.332411                   0
# 22               0.0248       0.11200  ...  0.316809                   0
# 50               0.0247       0.08400  ...  0.574414                   0
# 37               0.0485       0.70000  ...  0.223885                   0
# 36               0.0253       0.50600  ...  0.291960                   2
# 19               0.0315       0.86800  ...  0.956633                   0
# 25               0.0334       0.40900  ...  0.449652                   5
# 56               0.0487       0.49200  ...  0.583136                   2
# 27               0.0373       0.35300  ...  0.175511                   0
# 0                0.0719       0.78300  ...  0.509555                   2
#
#             predicted_genre  predicted_genre_prob  \
# Unnamed: 0
# 38                 opm rock              0.772751
# 57                 opm rock              0.760666
# 45             opm acoustic              0.724720
# 30                 opm rock              0.720334
# 24             opm acoustic              0.696404
# 41                 opm rock              0.690534
# 51                 opm rock              0.680188
# 15             opm acoustic              0.667071
# 35                 opm rock              0.662394
# 28                 opm rock              0.659961
# 31                 opm rock              0.644929
# 16             opm acoustic              0.640188
# 29             opm acoustic              0.639853
# 43                 opm rock              0.637282
# 32             opm acoustic              0.634885
# 52             opm acoustic              0.626310
# 11             opm acoustic              0.625226
# 54             opm acoustic              0.622268
# 21                 opm rock              0.620884
# 6              opm acoustic              0.609407
# 42             opm acoustic              0.608811
# 39                 opm rock              0.607768
# 3              opm acoustic              0.604411
# 2              opm acoustic              0.593945
# 4              opm acoustic              0.593136
# 13             opm acoustic              0.588935
# 5                  opm rock              0.587844
# 33             opm acoustic              0.582532
# 34             opm acoustic              0.574694
# 47                 opm rock              0.574585
# 53                 opm rock              0.561813
# 12             opm acoustic              0.545992
# 26             opm acoustic              0.545878
# 1              opm acoustic              0.540173
# 10                 opm jazz              0.538506
# 46                 opm rock              0.523798
# 49                 opm rock              0.522337
# 48             opm acoustic              0.518604
# 14             opm acoustic              0.503058
# 55             opm acoustic              0.486351
# 9              opm acoustic              0.479298
# 8                   opm rap              0.463373
# 18             opm acoustic              0.455394
# 7                   opm rap              0.451366
# 23                 opm rock              0.449967
# 40                 opm rock              0.448223
# 44             opm acoustic              0.434921
# 17             opm acoustic              0.398712
# 20             opm acoustic              0.394227
# 22             opm acoustic              0.389290
# 50             opm acoustic              0.381181
# 37             opm acoustic              0.369907
# 36                 opm jazz              0.365334
# 19             opm acoustic              0.363742
# 25                 opm rock              0.317058
# 56                 opm jazz              0.316880
# 27             opm acoustic              0.287841
# 0                  opm jazz              0.285337
#
#             predicted_opm acoustic_prob predicted_opm dance_prob  \
# Unnamed: 0
# 38                             0.074298                 0.027227
# 57                             0.022382                 0.073877
# 45                             0.724720                 0.009128
# 30                             0.036017                 0.038701
# 24                             0.696404                 0.007766
# 41                             0.153282                 0.018232
# 51                             0.107106                 0.016371
# 15                             0.667071                 0.017183
# 35                             0.088305                 0.020630
# 28                             0.072793                 0.036115
# 31                             0.166029                 0.037679
# 16                             0.640188                 0.019762
# 29                             0.639853                 0.024047
# 43                             0.101651                 0.018510
# 32                             0.634885                 0.019235
# 52                             0.626310                 0.024633
# 11                             0.625226                 0.019039
# 54                             0.622268                 0.032182
# 21                             0.031991                 0.100984
# 6                              0.609407                 0.025629
# 42                             0.608811                 0.019579
# 39                             0.163418                 0.014389
# 3                              0.604411                 0.025574
# 2                              0.593945                 0.010742
# 4                              0.593136                 0.024013
# 13                             0.588935                 0.023389
# 5                              0.230532                 0.014324
# 33                             0.582532                 0.031792
# 34                             0.574694                 0.022627
# 47                             0.249144                 0.022615
# 53                             0.261279                 0.015083
# 12                             0.545992                 0.039128
# 26                             0.545878                 0.027384
# 1                              0.540173                 0.026771
# 10                             0.153088                 0.027213
# 46                             0.021265                 0.090345
# 49                             0.289369                 0.017807
# 48                             0.518604                 0.025741
# 14                             0.503058                 0.028253
# 55                             0.486351                 0.038440
# 9                              0.479298                 0.026096
# 8                              0.103614                 0.017678
# 18                             0.455394                 0.017503
# 7                              0.267231                 0.020580
# 23                             0.075712                 0.029993
# 40                             0.217448                 0.019306
# 44                             0.364831                 0.020109
# 17                             0.398712                 0.038822
# 20                             0.375707                 0.014361
# 22                             0.170856                 0.021416
# 50                             0.192377                 0.017312
# 37                             0.369907                 0.027634
# 36                             0.265690                 0.018396
# 19                             0.363742                 0.047600
# 25                             0.262453                 0.017963
# 56                             0.172968                 0.018736
# 27                             0.256107                 0.019102
# 0                              0.249922                 0.038970
#
#             predicted_opm jazz_prob  predicted_opm rap_prob  \
# Unnamed: 0
# 38                         0.050168                0.029241
# 57                         0.026376                0.019883
# 45                         0.049510                0.095037
# 30                         0.064614                0.022088
# 24                         0.054716                0.104565
# 41                         0.080152                0.037548
# 51                         0.066376                0.079255
# 15                         0.137305                0.041380
# 35                         0.101263                0.067590
# 28                         0.098284                0.051965
# 31                         0.080397                0.055257
# 16                         0.152341                0.058247
# 29                         0.115500                0.037195
# 43                         0.192460                0.011115
# 32                         0.184068                0.044726
# 52                         0.184112                0.046898
# 11                         0.187727                0.049991
# 54                         0.124386                0.050884
# 21                         0.056194                0.142436
# 6                          0.197798                0.044199
# 42                         0.106790                0.040559
# 39                         0.114721                0.075462
# 3                          0.175755                0.035411
# 2                          0.077571                0.161108
# 4                          0.218734                0.065540
# 13                         0.156362                0.069948
# 5                          0.077101                0.069817
# 33                         0.152041                0.036179
# 34                         0.089406                0.035983
# 47                         0.107451                0.036971
# 53                         0.102377                0.048007
# 12                         0.128667                0.045758
# 26                         0.195132                0.076369
# 1                          0.185258                0.052009
# 10                         0.538506                0.061975
# 46                         0.035256                0.238040
# 49                         0.114837                0.042381
# 48                         0.201591                0.055532
# 14                         0.196512                0.110893
# 55                         0.168002                0.039195
# 9                          0.242955                0.103228
# 8                          0.346522                0.463373
# 18                         0.129589                0.072449
# 7                          0.140981                0.451366
# 23                         0.020848                0.309618
# 40                         0.189249                0.109696
# 44                         0.116418                0.054668
# 17                         0.194909                0.045457
# 20                         0.088034                0.113708
# 22                         0.043224                0.312724
# 50                         0.047604                0.296011
# 37                         0.255365                0.092648
# 36                         0.269834                0.062875
# 19                         0.164857                0.048869
# 25                         0.220882                0.160003
# 56                         0.240257                0.225348
# 27                         0.153780                0.263947
# 0                          0.285337                0.150280
#
#             predicted_opm reggae_prob  predicted_opm rock_prob
# Unnamed: 0
# 38                           0.046315                 0.772751
# 57                           0.096817                 0.760666
# 45                           0.013794                 0.107810
# 30                           0.118245                 0.720334
# 24                           0.016624                 0.119924
# 41                           0.020252                 0.690534
# 51                           0.050704                 0.680188
# 15                           0.004622                 0.132440
# 35                           0.059817                 0.662394
# 28                           0.080882                 0.659961
# 31                           0.015709                 0.644929
# 16                           0.004193                 0.125269
# 29                           0.006732                 0.176673
# 43                           0.038982                 0.637282
# 32                           0.006488                 0.110597
# 52                           0.008656                 0.109392
# 11                           0.011191                 0.106825
# 54                           0.005318                 0.164962
# 21                           0.047510                 0.620884
# 6                            0.013615                 0.109352
# 42                           0.006899                 0.217362
# 39                           0.024242                 0.607768
# 3                            0.017475                 0.141375
# 2                            0.013561                 0.143072
# 4                            0.009994                 0.088583
# 13                           0.015611                 0.145755
# 5                            0.020382                 0.587844
# 33                           0.010412                 0.187042
# 34                           0.010942                 0.266348
# 47                           0.009233                 0.574585
# 53                           0.011441                 0.561813
# 12                           0.009062                 0.231392
# 26                           0.035039                 0.120198
# 1                            0.017194                 0.178595
# 10                           0.048281                 0.170938
# 46                           0.091296                 0.523798
# 49                           0.013268                 0.522337
# 48                           0.018511                 0.180022
# 14                           0.034530                 0.126755
# 55                           0.014036                 0.253976
# 9                            0.019724                 0.128698
# 8                            0.017706                 0.051107
# 18                           0.012353                 0.312711
# 7                            0.036275                 0.083566
# 23                           0.113861                 0.449967
# 40                           0.016078                 0.448223
# 44                           0.009052                 0.434921
# 17                           0.021419                 0.300682
# 20                           0.013963                 0.394227
# 22                           0.062491                 0.389290
# 50                           0.065514                 0.381181
# 37                           0.024935                 0.229510
# 36                           0.017871                 0.365334
# 19                           0.017421                 0.357512
# 25                           0.021640                 0.317058
# 56                           0.025812                 0.316880
# 27                           0.019224                 0.287841
# 0                            0.024640                 0.250851
#
# [58 rows x 23 columns]

# %%
chart_tracks_df = chart_tracks_df[~chart_tracks_df['track_id'].isin(seed_track_data['track_id'].unique())]

# %%
median = seed_track_data.median()
# Out:
# C:\Users\andre\AppData\Local\Temp\ipykernel_18596\3969699176.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   median = seed_track_data.median()

# %%
mean = seed_track_data.mean()
# Out:
# C:\Users\andre\AppData\Local\Temp\ipykernel_18596\1159803872.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   mean = seed_track_data.mean()

# %% [markdown]
# ## 3. Explore Similarity Measures

# %%
from sklearn.metrics.pairwise import euclidean_distances, manhattan_distances, cosine_similarity

# %% [markdown]
# ##### Approach 1: Use audio features only

# %% [markdown]
# Euclidean

# %%
median[feature_cols].values.reshape(-1, 1)
# Out:
# array([[5.34000000e-01],
#        [3.77000000e-01],
#        [5.34316844e-01],
#        [3.19500000e-02],
#        [5.17500000e-01],
#        [5.25000000e-07],
#        [1.28500000e-01],
#        [2.97500000e-01],
#        [4.86492453e-01]])

# %%
chart_tracks_df['euclidean_dist'] = chart_tracks_df.apply(lambda x: euclidean_distances(x[feature_cols].values.reshape(-1, 1),\
                                                                  median[feature_cols].values.reshape(-1, 1))\
                                                                  .flatten()[0], axis=1)
#get top 10 nearest to seed_track_data
recommendation_df = chart_tracks_df.sort_values('euclidean_dist')[:10]
recommendation_df[['track_name','artist_name','euclidean_dist','predicted_genre']+feature_cols]
# Out:
#                       track_name       artist_name  euclidean_dist  \
# 78                 Carino Brutal         Slapshock           0.000
# 602  Ikaw At Ako (Movie Version)  Moira Dela Torre           0.000
# 212            Parallel Universe       Clara Benin           0.000
# 468          Starting over Again      Toni Gonzaga           0.001
# 507                Star Ng Pasko     Aiza Seguerra           0.002
# 115                Take That Man      IV Of Spades           0.003
# 303                   My Juliana      IV Of Spades           0.003
# 508                          214         Rivermaya           0.003
# 506             Out of My League    Stephen Speaks           0.004
# 537                  Kaibigan Mo    Sarah Geronimo           0.004
#
#     predicted_genre  danceability  energy  loudness  speechiness  \
# 78         opm rock         0.534   0.957  0.848801       0.1160
# 602    opm acoustic         0.534   0.486  0.591762       0.0316
# 212    opm acoustic         0.534   0.025  0.156433       0.0374
# 468    opm acoustic         0.535   0.441  0.756288       0.0293
# 507    opm acoustic         0.536   0.550  0.785171       0.0278
# 115        opm rock         0.531   0.838  0.737194       0.0386
# 303        opm rock         0.531   0.552  0.542767       0.0327
# 508    opm acoustic         0.537   0.561  0.733026       0.0297
# 506    opm acoustic         0.538   0.315  0.582990       0.0291
# 537        opm rock         0.530   0.534  0.661643       0.0347
#
#      acousticness  instrumentalness  liveness  valence     tempo
# 78       0.000031          0.000005    0.0683    0.368  0.485065
# 602      0.666000          0.000001    0.4000    0.369  0.556768
# 212      0.581000          0.000020    0.1080    0.179  0.546380
# 468      0.474000          0.000001    0.1080    0.256  0.450500
# 507      0.312000          0.000000    0.3470    0.175  0.269787
# 115      0.000540          0.019000    0.3740    0.682  0.634965
# 303      0.143000          0.000034    0.1030    0.234  0.739175
# 508      0.423000          0.000002    0.1340    0.242  0.179710
# 506      0.960000          0.005960    0.0979    0.400  0.269533
# 537      0.652000          0.000000    0.1180    0.476  0.581994

# %% [markdown]
# Manhattan

# %%
chart_tracks_df['manhattan_dist'] = chart_tracks_df.apply(lambda x: manhattan_distances(x[feature_cols].values.reshape(-1, 1),\
                                                                  median[feature_cols].values.reshape(-1, 1))\
                                                                  .flatten()[0], axis=1)
#get top 10 nearest to seed_track_data
recommendation_df = chart_tracks_df.sort_values('manhattan_dist')[:10]
recommendation_df[['track_name','artist_name','manhattan_dist','predicted_genre']+feature_cols]
# Out:
#                       track_name       artist_name  manhattan_dist  \
# 78                 Carino Brutal         Slapshock           0.000
# 602  Ikaw At Ako (Movie Version)  Moira Dela Torre           0.000
# 212            Parallel Universe       Clara Benin           0.000
# 468          Starting over Again      Toni Gonzaga           0.001
# 507                Star Ng Pasko     Aiza Seguerra           0.002
# 508                          214         Rivermaya           0.003
# 115                Take That Man      IV Of Spades           0.003
# 303                   My Juliana      IV Of Spades           0.003
# 506             Out of My League    Stephen Speaks           0.004
# 537                  Kaibigan Mo    Sarah Geronimo           0.004
#
#     predicted_genre  danceability  energy  loudness  speechiness  \
# 78         opm rock         0.534   0.957  0.848801       0.1160
# 602    opm acoustic         0.534   0.486  0.591762       0.0316
# 212    opm acoustic         0.534   0.025  0.156433       0.0374
# 468    opm acoustic         0.535   0.441  0.756288       0.0293
# 507    opm acoustic         0.536   0.550  0.785171       0.0278
# 508    opm acoustic         0.537   0.561  0.733026       0.0297
# 115        opm rock         0.531   0.838  0.737194       0.0386
# 303        opm rock         0.531   0.552  0.542767       0.0327
# 506    opm acoustic         0.538   0.315  0.582990       0.0291
# 537        opm rock         0.530   0.534  0.661643       0.0347
#
#      acousticness  instrumentalness  liveness  valence     tempo
# 78       0.000031          0.000005    0.0683    0.368  0.485065
# 602      0.666000          0.000001    0.4000    0.369  0.556768
# 212      0.581000          0.000020    0.1080    0.179  0.546380
# 468      0.474000          0.000001    0.1080    0.256  0.450500
# 507      0.312000          0.000000    0.3470    0.175  0.269787
# 508      0.423000          0.000002    0.1340    0.242  0.179710
# 115      0.000540          0.019000    0.3740    0.682  0.634965
# 303      0.143000          0.000034    0.1030    0.234  0.739175
# 506      0.960000          0.005960    0.0979    0.400  0.269533
# 537      0.652000          0.000000    0.1180    0.476  0.581994

# %% [markdown]
# Cosine

# %%
chart_tracks_df['cosine_dist'] = chart_tracks_df.apply(lambda x: 1-cosine_similarity(x[feature_cols].values.reshape(1, -1),\
                                                                  median[feature_cols].values.reshape(1, -1))\
                                                                  .flatten()[0], axis=1)
#get top 10 nearest to seed_track_data
recommendation_df = chart_tracks_df.sort_values('cosine_dist')[:10]
recommendation_df[['track_name','artist_name','cosine_dist','predicted_genre']+feature_cols]
# Out:
#                  track_name       artist_name  cosine_dist predicted_genre  \
# 473             We Can't Be            Krissy     0.004355    opm acoustic
# 472             We Can't Be            Krissy     0.004355    opm acoustic
# 469      Sana Ngayong Pasko  Silent Sanctuary     0.004804    opm acoustic
# 389                 Someday    Leanne & Naara     0.005175    opm acoustic
# 282         Why Can't It Be          Kaye Cal     0.005491    opm acoustic
# 424  Kahit Kunwari Man Lang           Agsunta     0.005735    opm acoustic
# 532                  Mahika       TJ Monterde     0.006452    opm acoustic
# 459             Dating Tayo       TJ Monterde     0.006514    opm acoustic
# 446              Heartbeats   Andrea Babierra     0.007026    opm acoustic
# 447              Heartbeats   Andrea Babierra     0.007026    opm acoustic
#
#      danceability  energy  loudness  speechiness  acousticness  \
# 473         0.516   0.310  0.483354       0.0279         0.565
# 472         0.516   0.310  0.483354       0.0279         0.565
# 469         0.678   0.387  0.591035       0.0295         0.667
# 389         0.581   0.325  0.529731       0.0461         0.616
# 282         0.563   0.314  0.622535       0.0312         0.612
# 424         0.631   0.440  0.551151       0.0435         0.529
# 532         0.545   0.490  0.734819       0.0289         0.557
# 459         0.551   0.329  0.550327       0.0431         0.648
# 446         0.620   0.420  0.523867       0.0283         0.715
# 447         0.620   0.420  0.523867       0.0283         0.715
#
#      instrumentalness  liveness  valence     tempo
# 473          0.000000    0.1130    0.330  0.510134
# 472          0.000000    0.1130    0.330  0.510134
# 469          0.000000    0.1860    0.369  0.498456
# 389          0.000000    0.1330    0.276  0.465845
# 282          0.000011    0.1240    0.272  0.503159
# 424          0.000000    0.1180    0.237  0.452161
# 532          0.000077    0.1270    0.372  0.582554
# 459          0.000038    0.0925    0.331  0.580717
# 446          0.009410    0.1110    0.320  0.556247
# 447          0.009410    0.1110    0.320  0.556247

# %% [markdown]
# View histograms of the 3 similarity measures

# %%
chart_tracks_df[['euclidean_dist','manhattan_dist','cosine_dist']].hist()
# Out:
# array([[<AxesSubplot:title={'center':'euclidean_dist'}>,
#         <AxesSubplot:title={'center':'manhattan_dist'}>],
#        [<AxesSubplot:title={'center':'cosine_dist'}>, <AxesSubplot:>]],
#       dtype=object)

# %% [markdown]
# ## 4. Modify similarity criteria

# %% [markdown]
# ##### Approach 2: Audio features and with same predicted genre

# %%
chart_tracks_df.head()
# Out:
#                  track_id       track_name               artist_id  \
# 0  4IvFOa1p68SZOYfnn81vv1        Samalamig  5GdspZ491zr64zzwVJJjJZ
# 1  19AlSgwI1midC2PU1TDkeF  Pekeng Kaibigan  1vcXQE9gZOF9PCAtdtT51L
# 2  54b8IPvheXDpro2VR2rWAS            Ivana  2EGJbNf0Hva2C2N6hvhMXD
# 3  5bSvsXRBUjGe8pGScU0hPz            Ivana  2EGJbNf0Hva2C2N6hvhMXD
# 4  0pobQmvHou3syiOi6DRqiC           Manila  4sEykiNSzZbkFkNXTb1bVd
#
#   artist_name                album_id  duration release_date  popularity  \
# 0     Shehyee  6NfArxsGcyiEJURN4NGgFc    253469   2002-12-18           2
# 1     Geo Ong  3A5uVKYCA9EJ6AIIIvHvdc    249085   2019-02-11           0
# 2   Soulstice  10stEx5J17TekHdjeh9dOJ    246550   2020-01-06           2
# 3   Soulstice  2zrFpbXrA54V8lCCQQhQRA    246550   2020-01-06           0
# 4      Hotdog  6KnvLQbkDLy4ZEpt8ONWYR    184146   2008-06-18           2
#
#    danceability  energy  ...  predicted_genre_prob  \
# 0         0.859   0.667  ...              0.982463
# 1         0.953   0.580  ...              0.980860
# 2         0.870   0.483  ...              0.973431
# 3         0.871   0.480  ...              0.972775
# 4         0.801   0.538  ...              0.944196
#
#    predicted_opm acoustic_prob  predicted_opm dance_prob  \
# 0                     0.000195                  0.002257
# 1                     0.000494                  0.005460
# 2                     0.000073                  0.001958
# 3                     0.000069                  0.002064
# 4                     0.004161                  0.006871
#
#    predicted_opm jazz_prob  predicted_opm rap_prob  predicted_opm reggae_prob  \
# 0                 0.005592                0.982463                   0.008270
# 1                 0.003030                0.980860                   0.009007
# 2                 0.001852                0.973431                   0.022299
# 3                 0.001744                0.972775                   0.022972
# 4                 0.018908                0.944196                   0.017624
#
#    predicted_opm rock_prob  euclidean_dist  manhattan_dist  cosine_dist
# 0                 0.001223           0.325           0.325     0.071779
# 1                 0.001149           0.419           0.419     0.078506
# 2                 0.000387           0.336           0.336     0.093341
# 3                 0.000376           0.337           0.337     0.094906
# 4                 0.008240           0.267           0.267     0.051680
#
# [5 rows x 32 columns]

# %%
seed_track_data.head()
# Out:
#                        track_name                track_id  \
# Unnamed: 0
# 38                       Lifetime  3X9c4tBzSdGhlO4Fx3WYgW
# 57                         Balita  62y4i6e9QVug3Nf7gf7i9P
# 45          Vie (Sabihin Mo Kung)  6FmoxZRTJrSCaZR3rjEv3W
# 30              Paninindigan Kita  5d9Rka4T0szdC1MobhtXrV
# 24                       Binibini  55RMhrPQYA6vLu5YMgXxFD
#
#                     artist_name  danceability  energy  key  loudness  mode  \
# Unnamed: 0
# 38                      Ben&Ben         0.386   0.657    7  0.865198     1
# 57          I Belong to the Zoo         0.485   0.891    2  1.000000     1
# 45                       NOBITA         0.686   0.271    7  0.488786     1
# 30                      Ben&Ben         0.624   0.596    4  0.534118     1
# 24                 Zack Tabudlo         0.642   0.374    5  0.429299     1
#
#             speechiness  acousticness  ...     tempo  predicted_genre_id  \
# Unnamed: 0                             ...
# 38               0.0316       0.29200  ...  0.999608                   5
# 57               0.0539       0.00711  ...  0.841267                   5
# 45               0.0346       0.45800  ...  0.557346                   0
# 30               0.0308       0.10700  ...  0.443196                   5
# 24               0.0320       0.42300  ...  0.581970                   0
#
#             predicted_genre  predicted_genre_prob  \
# Unnamed: 0
# 38                 opm rock              0.772751
# 57                 opm rock              0.760666
# 45             opm acoustic              0.724720
# 30                 opm rock              0.720334
# 24             opm acoustic              0.696404
#
#             predicted_opm acoustic_prob predicted_opm dance_prob  \
# Unnamed: 0
# 38                             0.074298                 0.027227
# 57                             0.022382                 0.073877
# 45                             0.724720                 0.009128
# 30                             0.036017                 0.038701
# 24                             0.696404                 0.007766
#
#             predicted_opm jazz_prob  predicted_opm rap_prob  \
# Unnamed: 0
# 38                         0.050168                0.029241
# 57                         0.026376                0.019883
# 45                         0.049510                0.095037
# 30                         0.064614                0.022088
# 24                         0.054716                0.104565
#
#             predicted_opm reggae_prob  predicted_opm rock_prob
# Unnamed: 0
# 38                           0.046315                 0.772751
# 57                           0.096817                 0.760666
# 45                           0.013794                 0.107810
# 30                           0.118245                 0.720334
# 24                           0.016624                 0.119924
#
# [5 rows x 23 columns]

# %%
seed_track_data.columns
# Out:
# Index(['track_name', 'track_id', 'artist_name', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo',
#        'predicted_genre_id', 'predicted_genre', 'predicted_genre_prob',
#        'predicted_opm acoustic_prob', 'predicted_opm dance_prob',
#        'predicted_opm jazz_prob', 'predicted_opm rap_prob',
#        'predicted_opm reggae_prob', 'predicted_opm rock_prob'],
#       dtype='object')

# %%
chart_tracks_df.columns
# Out:
# Index(['track_id', 'track_name', 'artist_id', 'artist_name', 'album_id',
#        'duration', 'release_date', 'popularity', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'streams',
#        'predicted_genre_id', 'predicted_genre', 'predicted_genre_prob',
#        'predicted_opm acoustic_prob', 'predicted_opm dance_prob',
#        'predicted_opm jazz_prob', 'predicted_opm rap_prob',
#        'predicted_opm reggae_prob', 'predicted_opm rock_prob',
#        'euclidean_dist', 'manhattan_dist', 'cosine_dist'],
#       dtype='object')

# %%
seed_track_data.mean()
# Out:
# C:\Users\andre\AppData\Local\Temp\ipykernel_18596\854078155.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   seed_track_data.mean()
# danceability                   0.536672
# energy                         0.403828
# key                            5.965517
# loudness                       0.511367
# mode                           0.879310
# speechiness                    0.037659
# acousticness                   0.524286
# instrumentalness               0.002667
# liveness                       0.179264
# valence                        0.318722
# tempo                          0.488628
# predicted_genre_id             1.879310
# predicted_genre_prob           0.544681
# predicted_opm acoustic_prob    0.362703
# predicted_opm dance_prob       0.026961
# predicted_opm jazz_prob        0.146491
# predicted_opm rap_prob         0.100395
# predicted_opm reggae_prob      0.028239
# predicted_opm rock_prob        0.335212
# dtype: float64

# %%
chart_tracks_df['predicted_genre']
# Out:
# 0           opm rap
# 1           opm rap
# 2           opm rap
# 3           opm rap
# 4           opm rap
#            ...
# 624        opm jazz
# 625        opm jazz
# 626       opm dance
# 627    opm acoustic
# 630         opm rap
# Name: predicted_genre, Length: 602, dtype: object

# %%
#get top 10 nearest to seed_track_data
recommendation_df = chart_tracks_df[chart_tracks_df['predicted_genre']=="opm acoustic"]\
                                    .sort_values('cosine_dist')[:10]
recommendation_df[['track_name','artist_name','cosine_dist','predicted_genre']+feature_cols]
# Out:
#                  track_name       artist_name  cosine_dist predicted_genre  \
# 472             We Can't Be            Krissy     0.004355    opm acoustic
# 473             We Can't Be            Krissy     0.004355    opm acoustic
# 469      Sana Ngayong Pasko  Silent Sanctuary     0.004804    opm acoustic
# 389                 Someday    Leanne & Naara     0.005175    opm acoustic
# 282         Why Can't It Be          Kaye Cal     0.005491    opm acoustic
# 424  Kahit Kunwari Man Lang           Agsunta     0.005735    opm acoustic
# 532                  Mahika       TJ Monterde     0.006452    opm acoustic
# 459             Dating Tayo       TJ Monterde     0.006514    opm acoustic
# 447              Heartbeats   Andrea Babierra     0.007026    opm acoustic
# 446              Heartbeats   Andrea Babierra     0.007026    opm acoustic
#
#      danceability  energy  loudness  speechiness  acousticness  \
# 472         0.516   0.310  0.483354       0.0279         0.565
# 473         0.516   0.310  0.483354       0.0279         0.565
# 469         0.678   0.387  0.591035       0.0295         0.667
# 389         0.581   0.325  0.529731       0.0461         0.616
# 282         0.563   0.314  0.622535       0.0312         0.612
# 424         0.631   0.440  0.551151       0.0435         0.529
# 532         0.545   0.490  0.734819       0.0289         0.557
# 459         0.551   0.329  0.550327       0.0431         0.648
# 447         0.620   0.420  0.523867       0.0283         0.715
# 446         0.620   0.420  0.523867       0.0283         0.715
#
#      instrumentalness  liveness  valence     tempo
# 472          0.000000    0.1130    0.330  0.510134
# 473          0.000000    0.1130    0.330  0.510134
# 469          0.000000    0.1860    0.369  0.498456
# 389          0.000000    0.1330    0.276  0.465845
# 282          0.000011    0.1240    0.272  0.503159
# 424          0.000000    0.1180    0.237  0.452161
# 532          0.000077    0.1270    0.372  0.582554
# 459          0.000038    0.0925    0.331  0.580717
# 447          0.009410    0.1110    0.320  0.556247
# 446          0.009410    0.1110    0.320  0.556247

# %% [markdown]
# ##### Approach 3: Predicted genre probabilities

# %%
genre_cols = [col for col in chart_tracks_df.columns if ('predicted_' in col)&('genre' not in col)]
genre_cols
# Out:
# ['predicted_opm acoustic_prob',
#  'predicted_opm dance_prob',
#  'predicted_opm jazz_prob',
#  'predicted_opm rap_prob',
#  'predicted_opm reggae_prob',
#  'predicted_opm rock_prob']

# %%
genre_cols

# %%
seed_track_data[cols].values.reshape(1, -1).flatten()[0]
# Out:
# 0.0742978961196232

# %%
genre_cols = [col for col in chart_tracks_df.columns if ('predicted_' in col)&('genre' not in col)]
cols = genre_cols
#cosine distance of audio features and predicted genre probabilities
chart_tracks_df['cosine_dist_mod1'] = chart_tracks_df.apply(lambda x: 1-cosine_similarity(x[cols].values.reshape(1, -1),\
                                                                  median[cols].values.reshape(1, -1))\
                                                                  .flatten()[0], axis=1)
recommendation_df = chart_tracks_df.sort_values('cosine_dist_mod1')[:10]
recommendation_df[['track_id','track_name','artist_name','cosine_dist_mod1','predicted_genre']+cols]
# Out:
#                    track_id                                    track_name  \
# 565  5f9808hpiCpuNyqqdXmpF2                                         Buwan
# 502  6pTTEPXrL8STDDeudUCt7z                             A Christmas Carol
# 516  6TbDpqKCksZNJjriFhPum8  Could I Love You Any More (feat. Jason Mraz)
# 556  3OpGUlDmRUXh0NkIYWoIlD                                     Your Song
# 523  6VeOvyaMBynIqMSY5uZpfx                                    Gusto Kita
# 558  02GtNoUv85fOPEaCTlpYzr               Kapit (From "Alone / Together")
# 575  1FHCU1rDAeaPsBW9byjJ0Q                                         12:51
# 602  459mgeXCLhqviFmgP2pYOo                   Ikaw At Ako (Movie Version)
# 473  696Gt2ZDsC1cxXEZo02azD                                   We Can't Be
# 472  0mqJsNkF3MRtBkRhzVskVX                                   We Can't Be
#
#           artist_name  cosine_dist_mod1 predicted_genre  \
# 565       juan karlos          0.004055    opm acoustic
# 502    Jose Mari Chan          0.005687    opm acoustic
# 516   Reneé Dominique          0.006432    opm acoustic
# 556  Parokya Ni Edgar          0.007654    opm acoustic
# 523   Angeline Quinto          0.007886    opm acoustic
# 558      Armi Millare          0.007920    opm acoustic
# 575   krissy & ericka          0.008073    opm acoustic
# 602  Moira Dela Torre          0.008207    opm acoustic
# 473            Krissy          0.008254    opm acoustic
# 472            Krissy          0.008254    opm acoustic
#
#      predicted_opm acoustic_prob  predicted_opm dance_prob  \
# 565                     0.400655                  0.015961
# 502                     0.459325                  0.046665
# 516                     0.448063                  0.042135
# 556                     0.411439                  0.030564
# 523                     0.443662                  0.028896
# 558                     0.411106                  0.051524
# 575                     0.393003                  0.039690
# 602                     0.367295                  0.030835
# 473                     0.486899                  0.024878
# 472                     0.486899                  0.024878
#
#      predicted_opm jazz_prob  predicted_opm rap_prob  \
# 565                 0.147749                0.113885
# 502                 0.114524                0.047852
# 516                 0.098895                0.073861
# 556                 0.113429                0.039419
# 523                 0.100767                0.045313
# 558                 0.115762                0.042248
# 575                 0.206633                0.035148
# 602                 0.184017                0.046482
# 473                 0.114284                0.031979
# 472                 0.114284                0.031979
#
#      predicted_opm reggae_prob  predicted_opm rock_prob
# 565                   0.013113                 0.308638
# 502                   0.010978                 0.320657
# 516                   0.007742                 0.329302
# 556                   0.049835                 0.355314
# 523                   0.015685                 0.365677
# 558                   0.013456                 0.365904
# 575                   0.017636                 0.307892
# 602                   0.022483                 0.348888
# 473                   0.009775                 0.332185
# 472                   0.009775                 0.332185

# %% [markdown]
# ##### Approach 4: Audio features and predicted genre probabilities

# %%
feature_cols + genre_cols
# Out:
# ['danceability',
#  'energy',
#  'loudness',
#  'speechiness',
#  'acousticness',
#  'instrumentalness',
#  'liveness',
#  'valence',
#  'tempo',
#  'predicted_opm acoustic_prob',
#  'predicted_opm dance_prob',
#  'predicted_opm jazz_prob',
#  'predicted_opm rap_prob',
#  'predicted_opm reggae_prob',
#  'predicted_opm rock_prob']

# %%
genre_cols = [col for col in chart_tracks_df.columns if ('predicted_' in col)&('genre' not in col)]
cols = feature_cols + genre_cols
#cosine distance of audio features and predicted genre probabilities
chart_tracks_df['cosine_dist_mod2'] = chart_tracks_df.apply(lambda x: 1-cosine_similarity(x[cols].values.reshape(1, -1),\
                                                                  median[cols].values.reshape(1, -1))\
                                                                  .flatten()[0], axis=1)
recommendation_df = chart_tracks_df.sort_values('cosine_dist_mod2')
recommendation_df[['track_id','track_name','artist_name','cosine_dist_mod2','predicted_genre']+cols]
# Out:
#                    track_id          track_name       artist_name  \
# 565  5f9808hpiCpuNyqqdXmpF2               Buwan       juan karlos
# 473  696Gt2ZDsC1cxXEZo02azD         We Can't Be            Krissy
# 472  0mqJsNkF3MRtBkRhzVskVX         We Can't Be            Krissy
# 459  267RumTt5KeLBGl2KWxBL0         Dating Tayo       TJ Monterde
# 469  4NZJUFjccdGUfRb7z7Igbd  Sana Ngayong Pasko  Silent Sanctuary
# ..                      ...                 ...               ...
# 391  1kORxnBnxk57ZDioKp9pQD           Kuwaderno           Ben&Ben
# 41   0AiUFrU3Bj0ZzYFSWoAM0O                Esmi           Because
# 46   7tQ2P3dP76bj1aSEfe8StO              Dantay              Kiyo
# 50   5LZqOdfYUXunyhHmPqGI6j                Lexi        Nik Makino
# 10   6aqH1me0AcXPwJEAflvNoT                Unan           Because
#
#      cosine_dist_mod2 predicted_genre  danceability  energy  loudness  \
# 565          0.007719    opm acoustic         0.631   0.381  0.498134
# 473          0.009060    opm acoustic         0.516   0.310  0.483354
# 472          0.009060    opm acoustic         0.516   0.310  0.483354
# 459          0.009688    opm acoustic         0.551   0.329  0.550327
# 469          0.009811    opm acoustic         0.678   0.387  0.591035
# ..                ...             ...           ...     ...       ...
# 391          0.317895    opm acoustic         0.227   0.349  0.265132
# 41           0.337644         opm rap         0.783   0.370  0.397965
# 46           0.348541         opm rap         0.387   0.360  0.273807
# 50           0.395129         opm rap         0.704   0.481  0.498716
# 10           0.434265         opm rap         0.634   0.242  0.231597
#
#      speechiness  acousticness  instrumentalness  liveness  valence     tempo  \
# 565       0.0400       0.44700          0.000171    0.0902   0.3600  0.491546
# 473       0.0279       0.56500          0.000000    0.1130   0.3300  0.510134
# 472       0.0279       0.56500          0.000000    0.1130   0.3300  0.510134
# 459       0.0431       0.64800          0.000038    0.0925   0.3310  0.580717
# 469       0.0295       0.66700          0.000000    0.1860   0.3690  0.498456
# ..           ...           ...               ...       ...      ...       ...
# 391       0.0343       0.86700          0.877000    0.1140   0.0856  0.232825
# 41        0.1170       0.13500          0.000000    0.0742   0.4030  0.165609
# 46        0.3120       0.81200          0.001950    0.0936   0.1400  0.130901
# 50        0.3720       0.00265          0.000000    0.1100   0.1780  0.159266
# 10        0.1530       0.19500          0.000000    0.1520   0.0725  0.201594
#
#      predicted_opm acoustic_prob  predicted_opm dance_prob  \
# 565                     0.400655                  0.015961
# 473                     0.486899                  0.024878
# 472                     0.486899                  0.024878
# 459                     0.495323                  0.025533
# 469                     0.489790                  0.023962
# ..                           ...                       ...
# 391                     0.548691                  0.035501
# 41                      0.017281                  0.018440
# 46                      0.004202                  0.002520
# 50                      0.000073                  0.004562
# 10                      0.008607                  0.001565
#
#      predicted_opm jazz_prob  predicted_opm rap_prob  \
# 565                 0.147749                0.113885
# 473                 0.114284                0.031979
# 472                 0.114284                0.031979
# 459                 0.178313                0.062585
# 469                 0.209430                0.067487
# ..                       ...                     ...
# 391                 0.170697                0.120337
# 41                  0.027361                0.833106
# 46                  0.157555                0.825577
# 50                  0.002009                0.816135
# 10                  0.034305                0.924616
#
#      predicted_opm reggae_prob  predicted_opm rock_prob
# 565                   0.013113                 0.308638
# 473                   0.009775                 0.332185
# 472                   0.009775                 0.332185
# 459                   0.012826                 0.225419
# 469                   0.017946                 0.191384
# ..                         ...                      ...
# 391                   0.004059                 0.120714
# 41                    0.088368                 0.015443
# 46                    0.009364                 0.000782
# 50                    0.176458                 0.000763
# 10                    0.023067                 0.007839
#
# [602 rows x 20 columns]

# %%
recommendation_df['track_id'].values
# Out:
# array(['5f9808hpiCpuNyqqdXmpF2', '696Gt2ZDsC1cxXEZo02azD',
#        '0mqJsNkF3MRtBkRhzVskVX', '267RumTt5KeLBGl2KWxBL0',
#        '4NZJUFjccdGUfRb7z7Igbd', '3gkwEytdCYIsrFdfEE2ALW',
#        '1FHCU1rDAeaPsBW9byjJ0Q', '5uBWj5DHsKw3DayLOuh7by',
#        '2B8ThVsaxp4aFeY5GnKNhS', '7bkAr4WNoTuSjpuh1NRQjm'], dtype=object)

# %%
reco_list = recommendation_df[['track_id','track_name','artist_name','cosine_dist_mod2','predicted_genre']+cols]

# %%
reco_list.to_csv("Song Recommendations2.csv", index=False, encoding='utf-8')
